# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5236, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'anarchism', 'a', 'of', 'term', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.121585
# Nearest to while: masculist, dominoes, estampie, governmental, mailbox, subplot, picirilli, van,
# Nearest to its: irvine, stanbul, flashing, polymorphic, frisch, commutator, switzer, stargate,
# Nearest to an: biomass, masterpieces, antiprism, footed, petrels, andante, receptor, sj,
# Nearest to d: eradicate, slavonia, pragmatic, chelmsford, ctrl, comstock, colorado, struma,
# Nearest to by: stoppage, hadadezer, crackers, azhar, puzzle, natively, optically, ironically,
# Nearest to s: indivisible, tuamotu, godzilla, paltrow, monogatari, unfolding, stuka, nacional,
# Nearest to history: ashcroft, zohar, honours, curative, heir, clerical, subduing, duplications,
# Nearest to however: cuon, gylfaginning, metroid, precise, musculus, crab, ceremony, imparts,
# Nearest to had: allophonic, syrian, pivots, unleavened, originates, comedies, cort, hybridized,
# Nearest to b: sterilization, hillary, pr, movies, sheikh, limitless, gne, episodes,
# Nearest to system: mannerism, sebasti, reciting, lcc, tarim, thebes, providing, comets,
# Nearest to two: ingots, norma, prepositional, lease, quark, falsifiability, increases, crag,
# Nearest to and: harwood, investigative, goi, seclusion, dietary, locarno, astros, veered,
# Nearest to they: organizational, cum, gillespie, savile, pray, inhibition, algebras, linnean,
# Nearest to war: schaff, migraine, directorial, sevens, blast, anesthesia, anc, callet,
# Nearest to will: marais, rhombicuboctahedron, jones, stine, rdoba, intercity, saucer, nourished,
# Average loss at step 2000: 4.366362
# Average loss at step 4000: 3.864401
# Average loss at step 6000: 3.791127
# Average loss at step 8000: 3.686818
# Average loss at step 10000: 3.619392
# Nearest to while: until, dominoes, speculative, hilltops, adonis, masculist, eazy, van,
# Nearest to its: his, their, the, desperate, voyager, salem, flashing, distributive,
# Nearest to an: the, zapatistas, antiprism, vab, infer, intimate, receptor, leech,
# Nearest to d: depressed, slavonia, beach, underrated, ctrl, representations, eradicate, shelf,
# Nearest to by: be, was, as, from, pushed, with, been, stoppage,
# Nearest to s: his, and, ethidium, ace, indivisible, flirted, clandestinely, sakhalin,
# Nearest to history: howell, rate, bedfordshire, retired, ashcroft, side, skewed, inside,
# Nearest to however: when, undertakes, zen, gallic, masterminded, renal, precise, florin,
# Nearest to had: has, have, was, were, brahms, syrian, originates, concert,
# Nearest to b: sheikh, nuremberg, byelorussian, gne, mand, hillary, bankrupt, pr,
# Nearest to system: tarim, mannerism, sebasti, ringworld, thebes, comets, state, terrorist,
# Nearest to two: three, five, four, zero, eight, six, nine, seven,
# Nearest to and: or, s, who, melisende, idm, which, in, gottorp,
# Nearest to they: he, we, savile, shipwreck, she, it, marking, wallonia,
# Nearest to war: migraine, schaff, zimri, comedians, ounce, callet, happening, guano,
# Nearest to will: may, would, borel, can, nourished, zubrin, lowers, avro,
# Average loss at step 12000: 3.606037
# Average loss at step 14000: 3.570022
# Average loss at step 16000: 3.410410
# Average loss at step 18000: 3.461163
# Average loss at step 20000: 3.543358
# Nearest to while: until, from, when, dominoes, were, hilltops, seekers, during,
# Nearest to its: their, his, the, some, pashtuns, any, an, exterior,
# Nearest to an: naturalization, wicket, the, antiprism, analogs, zapatistas, its, relevance,
# Nearest to d: b, beach, struma, underrated, excellence, shelf, slavonia, dorado,
# Nearest to by: with, be, were, penis, been, was, into, galactus,
# Nearest to s: realign, clandestinely, debugging, famously, microlensing, delicious, replacing, jackal,
# Nearest to history: bedfordshire, kla, side, howell, rate, metabolic, inside, skewed,
# Nearest to however: but, when, though, although, that, fart, ecumenical, sixties,
# Nearest to had: has, have, was, were, been, lux, semaphore, concert,
# Nearest to b: d, byelorussian, astronaut, sheikh, adi, gne, lonsdaleite, hw,
# Nearest to system: tarim, mannerism, bangor, rwandan, palais, sebasti, reciting, barley,
# Nearest to two: three, four, five, seven, six, eight, one, zero,
# Nearest to and: or, but, in, which, of, celery, while, savants,
# Nearest to they: he, we, there, it, she, shipwreck, you, who,
# Nearest to war: zimri, schaff, guano, comedians, ballad, ga, mackintosh, dy,
# Nearest to will: would, may, can, could, must, should, to, might,
# Average loss at step 22000: 3.496931
# Average loss at step 24000: 3.488452
# Average loss at step 26000: 3.477732
# Average loss at step 28000: 3.484293
# Average loss at step 30000: 3.500797
# Nearest to while: until, but, when, were, chanting, however, ecumenical, speculative,
# Nearest to its: their, the, his, andante, nationalistic, unmodified, landfall, pashtuns,
# Nearest to an: zapatistas, divisibility, infer, naturalization, headlined, arnaud, kohoutek, carnot,
# Nearest to d: b, excellence, einen, underrated, struma, linebackers, sapporo, slavonia,
# Nearest to by: was, in, from, as, with, psychoanalytic, under, were,
# Nearest to s: his, isbn, your, flirted, fledgling, panentheism, famously, whittaker,
# Nearest to history: bedfordshire, kla, side, ftc, period, metabolic, howell, vil,
# Nearest to however: but, although, when, though, that, if, tosk, there,
# Nearest to had: has, have, was, were, having, semaphore, since, is,
# Nearest to b: d, playfair, sapporo, byelorussian, astronaut, excellence, webcam, kannada,
# Nearest to system: tarim, rwandan, reciting, providing, bangor, barley, mannerism, includes,
# Nearest to two: three, four, one, seven, six, five, eight, zero,
# Nearest to and: or, in, who, of, against, deteriorated, american, sorties,
# Nearest to they: we, there, he, it, you, she, these, who,
# Nearest to war: guano, zimri, schaff, ballad, comedians, mackintosh, ga, badlands,
# Nearest to will: would, can, may, could, must, should, might, cannot,
# Average loss at step 32000: 3.499237
# Average loss at step 34000: 3.493191
# Average loss at step 36000: 3.453139
# Average loss at step 38000: 3.304228
# Average loss at step 40000: 3.426740
# Nearest to while: when, were, before, hateful, until, but, speculative, although,
# Nearest to its: their, his, the, her, pashtuns, baldrick, any, enough,
# Nearest to an: naturalization, wicket, zapatistas, counselling, the, analogs, infer, andante,
# Nearest to d: b, excellence, c, einen, UNK, e, f, sapporo,
# Nearest to by: with, millie, processor, was, sonnets, demolition, been, from,
# Nearest to s: his, frontier, singular, flirted, and, trios, your, yockey,
# Nearest to history: bedfordshire, list, kla, ftc, berlin, side, metabolic, period,
# Nearest to however: but, although, though, that, when, there, it, arran,
# Nearest to had: has, have, were, was, having, buffer, prelate, since,
# Nearest to b: d, UNK, c, astronaut, po, allude, f, eckhart,
# Nearest to system: systems, tarim, reciting, rwandan, profile, providing, aggregated, broadcasters,
# Nearest to two: three, four, five, seven, six, eight, nine, zero,
# Nearest to and: or, but, like, in, theoretically, including, subtracted, nimitz,
# Nearest to they: we, there, he, you, it, she, these, i,
# Nearest to war: zimri, schaff, comedians, guano, ballad, turning, scholarship, severn,
# Nearest to will: can, would, may, could, must, should, might, cannot,
# Average loss at step 42000: 3.432909
# Average loss at step 44000: 3.453954
# Average loss at step 46000: 3.452709
# Average loss at step 48000: 3.349841
# Average loss at step 50000: 3.381714
# Nearest to while: when, however, although, but, before, hateful, including, after,
# Nearest to its: their, his, the, enough, honored, her, petr, desperate,
# Nearest to an: naturalization, analogs, juliette, counselling, wicket, icrc, migrant, divisibility,
# Nearest to d: b, f, e, c, excellence, leak, allman, einen,
# Nearest to by: was, through, with, boycotted, been, demolition, ugarit, constructivism,
# Nearest to s: whose, his, sinuous, your, anton, fledgling, dat, flirted,
# Nearest to history: list, bedfordshire, kla, peer, observant, leader, turin, carbohydrates,
# Nearest to however: but, although, though, that, when, while, where, if,
# Nearest to had: has, have, having, was, since, were, semaphore, robust,
# Nearest to b: d, wuppertal, astronaut, allude, donna, c, f, recruiting,
# Nearest to system: systems, tarim, reciting, rwandan, broadcasters, xry, abc, profile,
# Nearest to two: three, one, six, five, four, eight, seven, zero,
# Nearest to and: or, but, whose, of, although, sorties, geometric, like,
# Nearest to they: we, there, he, you, she, it, not, these,
# Nearest to war: zimri, schaff, ballad, scholarship, comedians, badlands, turning, janeiro,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Average loss at step 52000: 3.434216
# Average loss at step 54000: 3.430376
# Average loss at step 56000: 3.439116
# Average loss at step 58000: 3.394514
# Average loss at step 60000: 3.389159
# Nearest to while: although, when, before, were, resultant, after, however, este,
# Nearest to its: their, his, the, her, enough, conceits, honored, uncollected,
# Nearest to an: analogs, naturalization, antiprism, app, migrant, infer, biomass, affordable,
# Nearest to d: b, c, f, einen, allman, e, excellence, sowell,
# Nearest to by: through, psychoanalytic, without, was, with, using, prentice, millie,
# Nearest to s: whose, bethlen, isbn, flirted, hellbender, your, fledgling, shaanxi,
# Nearest to history: list, politics, period, bedfordshire, origin, map, geography, kla,
# Nearest to however: although, but, though, when, that, which, there, while,
# Nearest to had: has, have, was, having, were, gave, electroplating, since,
# Nearest to b: d, c, f, h, carrera, eckhart, donna, postgraduate,
# Nearest to system: systems, tarim, broadcasters, state, xry, reciting, schooled, abc,
# Nearest to two: three, four, five, six, one, seven, eight, zero,
# Nearest to and: or, but, than, including, intentionally, although, mercator, reefs,
# Nearest to they: we, there, you, he, she, it, these, shipwreck,
# Nearest to war: zimri, schaff, blockading, janeiro, marcy, severn, ballad, wars,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Average loss at step 62000: 3.243060
# Average loss at step 64000: 3.259051
# Average loss at step 66000: 3.397151
# Average loss at step 68000: 3.396758
# Average loss at step 70000: 3.355511
# Nearest to while: although, before, when, however, including, though, after, are,
# Nearest to its: their, his, the, her, enough, underscore, honored, your,
# Nearest to an: naturalization, analogs, the, berb, dagestan, app, counselling, zapatistas,
# Nearest to d: b, f, einen, excellence, leak, e, h, fanpage,
# Nearest to by: through, psychoanalytic, using, was, in, is, egress, processor,
# Nearest to s: isbn, coffins, outcomes, your, swept, the, whose, catenary,
# Nearest to history: list, period, bedfordshire, origin, inge, altruism, berlin, commissioner,
# Nearest to however: but, although, though, that, where, when, while, which,
# Nearest to had: has, have, was, were, having, been, subsequently, since,
# Nearest to b: d, r, f, x, astronaut, h, te, carrera,
# Nearest to system: systems, state, broadcasters, xry, application, tarim, reciting, dukakis,
# Nearest to two: three, four, six, five, seven, one, zero, eight,
# Nearest to and: or, of, which, but, criminally, sluggish, than, interstellar,
# Nearest to they: we, there, you, he, it, she, these, who,
# Nearest to war: zimri, blockading, janeiro, wars, ballad, scholarship, schaff, severn,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Average loss at step 72000: 3.371747
# Average loss at step 74000: 3.345261
# Average loss at step 76000: 3.321182
# Average loss at step 78000: 3.346031
# Average loss at step 80000: 3.380080
# Nearest to while: although, before, when, after, though, however, but, during,
# Nearest to its: their, his, her, the, your, our, my, whose,
# Nearest to an: analogs, counselling, naturalization, antiprism, app, biomass, wicket, dagestan,
# Nearest to d: b, f, einen, te, e, leak, des, p,
# Nearest to by: psychoanalytic, ugarit, through, when, defying, demolition, prentice, stoppage,
# Nearest to s: whose, homoerotic, catenary, isbn, wilmington, omphale, realign, pomp,
# Nearest to history: list, period, chester, version, study, politics, consists, bedfordshire,
# Nearest to however: although, but, though, that, while, when, where, ago,
# Nearest to had: have, has, having, was, were, electroplating, semaphore, since,
# Nearest to b: d, r, c, f, astronaut, te, x, p,
# Nearest to system: systems, reciting, xry, tarim, broadcasters, application, program, dukakis,
# Nearest to two: three, four, six, five, one, seven, eight, zero,
# Nearest to and: or, but, atrophy, while, interstellar, ashford, including, heinrich,
# Nearest to they: we, he, there, you, she, it, these, who,
# Nearest to war: wars, zimri, blockading, severn, ballad, bijection, battle, scholarship,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Average loss at step 82000: 3.401658
# Average loss at step 84000: 3.409112
# Average loss at step 86000: 3.386711
# Average loss at step 88000: 3.353158
# Average loss at step 90000: 3.363580
# Nearest to while: although, before, when, though, during, but, until, after,
# Nearest to its: their, his, the, her, my, your, enough, our,
# Nearest to an: analogs, naturalization, antiprism, another, berb, the, wicket, counselling,
# Nearest to d: b, f, fanpage, underrated, contributed, wuppertal, leak, des,
# Nearest to by: psychoanalytic, millie, when, through, laurier, without, with, during,
# Nearest to s: his, your, whose, isbn, realign, nyi, pomp, fledgling,
# Nearest to history: list, period, version, politics, ftc, underside, study, prick,
# Nearest to however: but, although, though, that, where, while, since, ago,
# Nearest to had: has, have, was, were, having, since, electroplating, never,
# Nearest to b: d, r, te, f, y, sample, c, incomes,
# Nearest to system: systems, program, reciting, tarim, state, crux, iras, xry,
# Nearest to two: three, four, five, seven, eight, six, one, zero,
# Nearest to and: or, but, while, including, reefs, of, interstellar, contextual,
# Nearest to they: we, he, you, there, it, she, these, not,
# Nearest to war: wars, zimri, battle, during, blockading, scholarship, ballad, preludes,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Average loss at step 92000: 3.398624
# Average loss at step 94000: 3.258136
# Average loss at step 96000: 3.356955
# Average loss at step 98000: 3.240793
# Average loss at step 100000: 3.358679
# Nearest to while: although, when, before, though, where, but, heyerdahl, after,
# Nearest to its: their, his, the, her, baldrick, whose, enough, uncollected,
# Nearest to an: analogs, naturalization, wicket, picchi, antiprism, biomass, relevance, counselling,
# Nearest to d: b, f, po, einen, te, c, linda, vol,
# Nearest to by: when, psychoanalytic, without, through, sonnets, millie, including, ugarit,
# Nearest to s: whose, his, nyi, your, realign, homoerotic, my, isbn,
# Nearest to history: list, amherst, extravagance, inge, map, prick, period, glaukos,
# Nearest to however: but, although, that, though, where, especially, while, when,
# Nearest to had: has, have, was, having, were, would, electroplating, since,
# Nearest to b: d, adrian, astronaut, cooley, te, kannada, po, playfair,
# Nearest to system: systems, program, tarim, reciting, xry, machines, broadcasters, representation,
# Nearest to two: four, three, five, six, seven, eight, zero, one,
# Nearest to and: or, but, disneyland, singin, like, including, of, drang,
# Nearest to they: we, there, he, you, she, it, not, these,
# Nearest to war: wars, battle, zimri, ballad, gruesome, scholarship, reception, preludes,
# Nearest to will: would, can, could, must, should, may, might, cannot,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
